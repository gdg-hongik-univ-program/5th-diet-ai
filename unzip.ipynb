# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive
# Out:
# '01월 - 2021 가정교리대상 초대 편지.jpg'
# '01월 - 2021 가정교리대상 초대 편지.pptx'
# '01_[참가신청서]_2025년_GovTech_창업경진대회.hwp'
# '02_[개인정보동의서]_2025년_GovTech_창업경진대회.hwp'
# '02월 - 2021첫영성체 신청대상자명단.hwp'
# '03_[서약서]_2025년_GovTech_창업경진대회.hwp'
# '04_[아이디어 기획서]_2025년_GovTech_창업경진대회.hwp'
# '1등급 만들기'
# '1등급 만들기 물리학 파동편 답지.pdf'
# '1등급 만들기 지구과학 답지.pdf'
# '1등급 만들기 지구과학 문제.pdf'
# '1등습 만들기 물리학 파동편 문제.pdf'
# '2020. 04. 09. 12.43.58_20200409124540.pdf'
# '2020. 04. 09. 12.43.58_20200409124608.pdf'
#  20201230204041667.jpg
#  20201230204041667.pdf
# '2020년 10월 고3 이투스 전국 모의고사 영어 듣기.mp3'
#  20210129_204522.jpg
#  20210129_204701.jpg
# '2021년 첫영성체 대상자 부모님이름표.pptx'
# '2021 첫만남준비(수정).docx'
#  20220329_144228.jpg
#  20220329_144410.jpg
# '20220329_144523 (1).jpg'
# ...

# %%
# %%bash
# set +e
# # 대상 폴더 경로 (본인의 경로에 맞게 수정하세요)
# BASE_PATH="/content/drive/MyDrive/법률 규정 텍스트 분석 데이터 (고도화)- 상황에 따른 판례 데이터(Sublabel)"
#
# find "$BASE_PATH" -name "*.zip" | while read z; do
#   # 1. 파일이 들어있는 디렉토리 경로 추출 (예: /content/Training/cat)
#   d=$(dirname "$z")
#
#   # 2. 파일명에서 확장자 제거 (예: data.zip -> data)
#   folder_name=$(basename "$z" .zip)
#
#   # 3. 새로운 목적지 경로 생성 (예: /content/Training/cat/data)
#   target_dir="$d/$folder_name"
#
#   echo "Unzipping $z into $target_dir"
#
#   # 4. 압축 해제 (-d 옵션이 폴더를 자동으로 생성해줍니다)
#   unzip -O cp949 -o -qq "$z" -d "$target_dir" || echo "Failed: $z"
# done
# Out:
# Process is interrupted.

# %%
# %%bash
# set +e
# # 대상 폴더 경로 (본인의 경로에 맞게 수정하세요)
# BASE_PATH="/content/drive/MyDrive/법률 규정 텍스트 분석 데이터 (고도화)- 상황에 따른 판례 데이터(Other)"
#
# find "$BASE_PATH" -name "*.zip" | while read z; do
#   # 1. 파일이 들어있는 디렉토리 경로 추출 (예: /content/Training/cat)
#   d=$(dirname "$z")
#
#   # 2. 파일명에서 확장자 제거 (예: data.zip -> data)
#   folder_name=$(basename "$z" .zip)
#
#   # 3. 새로운 목적지 경로 생성 (예: /content/Training/cat/data)
#   target_dir="$d/$folder_name"
#
#   echo "Unzipping $z into $target_dir"
#
#   # 4. 압축 해제 (-d 옵션이 폴더를 자동으로 생성해줍니다)
#   unzip -O cp949 -o -qq "$z" -d "$target_dir" || echo "Failed: $z"
# done
# Out:
# Process is interrupted.

# %%
# %%bash
# # 대상 디렉토리 설정 (본인의 경로로 수정하세요)
# TARGET_DIR="/content/drive/MyDrive/행정법 LLM 사전학습 및 Instruction Tuning 데이터(Training)/02.라벨링데이터"
#
# echo "--- 폴더별 파일 개수 리포트 ---"
#
# # 해당 디렉토리 내의 모든 폴더(디렉토리)를 찾아 반복문 실행
# for d in "$TARGET_DIR"/*/; do
#     # 폴더 이름만 추출
#     folder_name=$(basename "$d")
#
#     # 해당 폴더 내의 모든 파일(-type f) 개수 세기 (하위 폴더 포함)
#     count=$(find "$d" -type f | wc -l)
#
#     echo "[$folder_name]: $count 개"
# done
#
# echo "------------------------------"
# Out:
# --- 폴더별 파일 개수 리포트 ---
# [TL_결정례_QA]: 5165 개
# [TL_결정례_SUM]: 4959 개
# [TL_법령_QA]: 31851 개
# [TL_판결문_QA]: 12892 개
# [TL_판결문_SUM]: 17920 개
# [TL_해석례_QA]: 4081 개
# [TL_해석례_SUM]: 3132 개
# ------------------------------

# %%
drive.flush_and_unmount()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1879632601.py in <cell line: 0>()
# ----> 1 drive.flush_and_unmount()
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in flush_and_unmount(timeout_ms)
#      86       stderr=_subprocess.PIPE,
#      87   )
# ---> 88   out, err = p.communicate()
#      89   if mount._DEBUG:  # pylint:disable=protected-access
#      90     print('flush_and_unmount: out: {}\nerr: {}'.format(out, err))
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
# ...
